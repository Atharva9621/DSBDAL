# %% [markdown]
# <div style="position: relative; width: 100%; height: 300px; display: flex; justify-content: center; align-items: center;">
#     <img src="data:image/jpeg;base64,..." style="position: absolute; top: 0; left: 0; width: 100%; height: 100%; z-index: 0; opacity: 1.0; border-radius: 37px" >
#     <div style="border-radius: 10px; position: relative; z-index: 1; text-align: center; background-color: rgba(50, 50, 50, 0.5); color: rgb(255, 150, 150); display: flex; flex-direction: column; align-items: center; text-align: center; justify-content: center; width: 100%; margin: 10%; padding: 5px ">
#             <h1 style="text-align: center; width: 100%" >Data Analytics - Social Media </h1>
#     </div>
# </div>

# %% [markdown]
# <h1 style="text-align: center; font-family: 'Roboto', sans-serif; color: rgb(230, 131, 131); background-color: rgba(146, 146, 255, 0.5); padding: 30px; border-style: solid; border-radius: 10px;"> Imports & Load Data </h1>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

sns.set()
sns.set_palette('bwr')
SNS_CMAP = 'bwr'

colors = sns.palettes.color_palette(SNS_CMAP)

pd.options.mode.chained_assignment = None

# %%
# df = pd.read_csv('/kaggle/input/social-network-ads/Social_Network_Ads.csv')
df = pd.read_csv('Social_Network_Ads.csv')

# %% [markdown]
# <h1 style="text-align: center; font-family: 'Roboto', sans-serif; color: rgb(230, 131, 131); background-color: rgba(146, 146, 255, 0.5); padding: 30px; border-style: solid; border-radius: 10px;"> EDA </h1>

# %%
df.head().style.background_gradient(cmap=SNS_CMAP)
# Out:
# <style type="text/css">
# #T_273c1_row0_col0 {
#   background-color: #3434ff;
#   color: #f1f1f1;
# }
# #T_273c1_row0_col2, #T_273c1_row0_col3, #T_273c1_row0_col4, #T_273c1_row1_col4, #T_273c1_row2_col4, #T_273c1_row3_col0, #T_273c1_row3_col4, #T_273c1_row4_col2, #T_273c1_row4_col4 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_273c1_row1_col0, #T_273c1_row1_col2, #T_273c1_row4_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_273c1_row1_col3 {
#   background-color: #0808ff;
#   color: #f1f1f1;
# }
# #T_273c1_row2_col0 {
#   background-color: #a0a0ff;
#   color: #f1f1f1;
# }
# #T_273c1_row2_col2 {
#   background-color: #e0e0ff;
#   color: #000000;
# }
# #T_273c1_row2_col3 {
#   background-color: #d6d6ff;
#   color: #000000;
# }
# #T_273c1_row3_col2 {
#   background-color: #fffefe;
#   color: #000000;
# }
# #T_273c1_row3_col3 {
#   background-color: #ffaaaa;
#   color: #000000;
# }
# #T_273c1_row4_col0 {
#   background-color: #ff1010;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_273c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_273c1_level0_col0" class="col_heading level0 col0" >User ID</th>
#       <th id="T_273c1_level0_col1" class="col_heading level0 col1" >Gender</th>
#       <th id="T_273c1_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_273c1_level0_col3" class="col_heading level0 col3" >EstimatedSalary</th>
#       <th id="T_273c1_level0_col4" class="col_heading level0 col4" >Purchased</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_273c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_273c1_row0_col0" class="data row0 col0" >15624510</td>
#       <td id="T_273c1_row0_col1" class="data row0 col1" >Male</td>
#       <td id="T_273c1_row0_col2" class="data row0 col2" >19</td>
#       <td id="T_273c1_row0_col3" class="data row0 col3" >19000</td>
#       <td id="T_273c1_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_273c1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_273c1_row1_col0" class="data row1 col0" >15810944</td>
#       <td id="T_273c1_row1_col1" class="data row1 col1" >Male</td>
#       <td id="T_273c1_row1_col2" class="data row1 col2" >35</td>
#       <td id="T_273c1_row1_col3" class="data row1 col3" >20000</td>
#       <td id="T_273c1_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_273c1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_273c1_row2_col0" class="data row2 col0" >15668575</td>
#       <td id="T_273c1_row2_col1" class="data row2 col1" >Female</td>
#       <td id="T_273c1_row2_col2" class="data row2 col2" >26</td>
#       <td id="T_273c1_row2_col3" class="data row2 col3" >43000</td>
#       <td id="T_273c1_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_273c1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_273c1_row3_col0" class="data row3 col0" >15603246</td>
#       <td id="T_273c1_row3_col1" class="data row3 col1" >Female</td>
#       <td id="T_273c1_row3_col2" class="data row3 col2" >27</td>
#       <td id="T_273c1_row3_col3" class="data row3 col3" >57000</td>
#       <td id="T_273c1_row3_col4" class="data row3 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_273c1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_273c1_row4_col0" class="data row4 col0" >15804002</td>
#       <td id="T_273c1_row4_col1" class="data row4 col1" >Male</td>
#       <td id="T_273c1_row4_col2" class="data row4 col2" >19</td>
#       <td id="T_273c1_row4_col3" class="data row4 col3" >76000</td>
#       <td id="T_273c1_row4_col4" class="data row4 col4" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.describe().iloc[1:].style.background_gradient(cmap=SNS_CMAP)
# Out:
# <style type="text/css">
# #T_b110c_row0_col0 {
#   background-color: #ff0404;
#   color: #f1f1f1;
# }
# #T_b110c_row0_col1 {
#   background-color: #ffe6e6;
#   color: #000000;
# }
# #T_b110c_row0_col2 {
#   background-color: #ceceff;
#   color: #000000;
# }
# #T_b110c_row0_col3 {
#   background-color: #b6b6ff;
#   color: #000000;
# }
# #T_b110c_row1_col0, #T_b110c_row1_col1, #T_b110c_row2_col2, #T_b110c_row2_col3, #T_b110c_row3_col3, #T_b110c_row4_col3 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_b110c_row1_col2 {
#   background-color: #4848ff;
#   color: #f1f1f1;
# }
# #T_b110c_row1_col3 {
#   background-color: #f4f4ff;
#   color: #000000;
# }
# #T_b110c_row2_col0 {
#   background-color: #ff0808;
#   color: #f1f1f1;
# }
# #T_b110c_row2_col1 {
#   background-color: #4c4cff;
#   color: #f1f1f1;
# }
# #T_b110c_row3_col0 {
#   background-color: #ff0606;
#   color: #f1f1f1;
# }
# #T_b110c_row3_col1 {
#   background-color: #c6c6ff;
#   color: #000000;
# }
# #T_b110c_row3_col2 {
#   background-color: #6a6aff;
#   color: #f1f1f1;
# }
# #T_b110c_row4_col0, #T_b110c_row5_col0 {
#   background-color: #ff0202;
#   color: #f1f1f1;
# }
# #T_b110c_row4_col1 {
#   background-color: #ffecec;
#   color: #000000;
# }
# #T_b110c_row4_col2 {
#   background-color: #d0d0ff;
#   color: #000000;
# }
# #T_b110c_row5_col1 {
#   background-color: #ff9090;
#   color: #000000;
# }
# #T_b110c_row5_col2 {
#   background-color: #ffeaea;
#   color: #000000;
# }
# #T_b110c_row5_col3, #T_b110c_row6_col0, #T_b110c_row6_col1, #T_b110c_row6_col2, #T_b110c_row6_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b110c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b110c_level0_col0" class="col_heading level0 col0" >User ID</th>
#       <th id="T_b110c_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_b110c_level0_col2" class="col_heading level0 col2" >EstimatedSalary</th>
#       <th id="T_b110c_level0_col3" class="col_heading level0 col3" >Purchased</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b110c_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_b110c_row0_col0" class="data row0 col0" >15691539.757500</td>
#       <td id="T_b110c_row0_col1" class="data row0 col1" >37.655000</td>
#       <td id="T_b110c_row0_col2" class="data row0 col2" >69742.500000</td>
#       <td id="T_b110c_row0_col3" class="data row0 col3" >0.357500</td>
#     </tr>
#     <tr>
#       <th id="T_b110c_level0_row1" class="row_heading level0 row1" >std</th>
#       <td id="T_b110c_row1_col0" class="data row1 col0" >71658.321581</td>
#       <td id="T_b110c_row1_col1" class="data row1 col1" >10.482877</td>
#       <td id="T_b110c_row1_col2" class="data row1 col2" >34096.960282</td>
#       <td id="T_b110c_row1_col3" class="data row1 col3" >0.479864</td>
#     </tr>
#     <tr>
#       <th id="T_b110c_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_b110c_row2_col0" class="data row2 col0" >15566689.000000</td>
#       <td id="T_b110c_row2_col1" class="data row2 col1" >18.000000</td>
#       <td id="T_b110c_row2_col2" class="data row2 col2" >15000.000000</td>
#       <td id="T_b110c_row2_col3" class="data row2 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b110c_level0_row3" class="row_heading level0 row3" >25%</th>
#       <td id="T_b110c_row3_col0" class="data row3 col0" >15626763.750000</td>
#       <td id="T_b110c_row3_col1" class="data row3 col1" >29.750000</td>
#       <td id="T_b110c_row3_col2" class="data row3 col2" >43000.000000</td>
#       <td id="T_b110c_row3_col3" class="data row3 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b110c_level0_row4" class="row_heading level0 row4" >50%</th>
#       <td id="T_b110c_row4_col0" class="data row4 col0" >15694341.500000</td>
#       <td id="T_b110c_row4_col1" class="data row4 col1" >37.000000</td>
#       <td id="T_b110c_row4_col2" class="data row4 col2" >70000.000000</td>
#       <td id="T_b110c_row4_col3" class="data row4 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b110c_level0_row5" class="row_heading level0 row5" >75%</th>
#       <td id="T_b110c_row5_col0" class="data row5 col0" >15750363.000000</td>
#       <td id="T_b110c_row5_col1" class="data row5 col1" >46.000000</td>
#       <td id="T_b110c_row5_col2" class="data row5 col2" >88000.000000</td>
#       <td id="T_b110c_row5_col3" class="data row5 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b110c_level0_row6" class="row_heading level0 row6" >max</th>
#       <td id="T_b110c_row6_col0" class="data row6 col0" >15815236.000000</td>
#       <td id="T_b110c_row6_col1" class="data row6 col1" >60.000000</td>
#       <td id="T_b110c_row6_col2" class="data row6 col2" >150000.000000</td>
#       <td id="T_b110c_row6_col3" class="data row6 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
agg_df = df.agg(["nunique", "unique", lambda x:x.isna().sum(), "dtypes"]).T
agg_df['unique'] = agg_df['unique'].apply(lambda x: x if len(x)<10 else x[:10])
agg_df.style.apply(lambda s: ['background-color: rgba(230, 131, 131, 0.5)' if i % 2 == 0 else 'background-color: rgba(146, 146, 255, 0.5)' for i in range(len(s))])
# Out:
# <style type="text/css">
# #T_93bcb_row0_col0, #T_93bcb_row0_col1, #T_93bcb_row0_col2, #T_93bcb_row0_col3, #T_93bcb_row2_col0, #T_93bcb_row2_col1, #T_93bcb_row2_col2, #T_93bcb_row2_col3, #T_93bcb_row4_col0, #T_93bcb_row4_col1, #T_93bcb_row4_col2, #T_93bcb_row4_col3 {
#   background-color: rgba(230, 131, 131, 0.5);
# }
# #T_93bcb_row1_col0, #T_93bcb_row1_col1, #T_93bcb_row1_col2, #T_93bcb_row1_col3, #T_93bcb_row3_col0, #T_93bcb_row3_col1, #T_93bcb_row3_col2, #T_93bcb_row3_col3 {
#   background-color: rgba(146, 146, 255, 0.5);
# }
# </style>
# <table id="T_93bcb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93bcb_level0_col0" class="col_heading level0 col0" >nunique</th>
#       <th id="T_93bcb_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_93bcb_level0_col2" class="col_heading level0 col2" ><lambda></th>
#       <th id="T_93bcb_level0_col3" class="col_heading level0 col3" >dtypes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93bcb_level0_row0" class="row_heading level0 row0" >User ID</th>
#       <td id="T_93bcb_row0_col0" class="data row0 col0" >400</td>
#       <td id="T_93bcb_row0_col1" class="data row0 col1" >[15624510 15810944 15668575 15603246 15804002 15728773 15598044 15694829
#  15600575 15727311]</td>
#       <td id="T_93bcb_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_93bcb_row0_col3" class="data row0 col3" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_93bcb_level0_row1" class="row_heading level0 row1" >Gender</th>
#       <td id="T_93bcb_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_93bcb_row1_col1" class="data row1 col1" >['Male' 'Female']</td>
#       <td id="T_93bcb_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_93bcb_row1_col3" class="data row1 col3" >object</td>
#     </tr>
#     <tr>
#       <th id="T_93bcb_level0_row2" class="row_heading level0 row2" >Age</th>
#       <td id="T_93bcb_row2_col0" class="data row2 col0" >43</td>
#       <td id="T_93bcb_row2_col1" class="data row2 col1" >[19 35 26 27 32 25 20 18 29 47]</td>
#       <td id="T_93bcb_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_93bcb_row2_col3" class="data row2 col3" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_93bcb_level0_row3" class="row_heading level0 row3" >EstimatedSalary</th>
#       <td id="T_93bcb_row3_col0" class="data row3 col0" >117</td>
#       <td id="T_93bcb_row3_col1" class="data row3 col1" >[ 19000  20000  43000  57000  76000  58000  84000 150000  33000  65000]</td>
#       <td id="T_93bcb_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_93bcb_row3_col3" class="data row3 col3" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_93bcb_level0_row4" class="row_heading level0 row4" >Purchased</th>
#       <td id="T_93bcb_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_93bcb_row4_col1" class="data row4 col1" >[0 1]</td>
#       <td id="T_93bcb_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_93bcb_row4_col3" class="data row4 col3" >int64</td>
#     </tr>
#   </tbody>
# </table>

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
sns.heatmap(df.select_dtypes(include=numerics).corr(), cmap=SNS_CMAP, annot=True, annot_kws={'fontsize':7}, fmt='.1g', vmin=-1, vmax=1, center= 0)
plt.title("Feature Correlation")
plt.show()

# %%
cols = df.columns.drop(['User ID', 'Purchased', 'Gender'])
accent1 = {0: colors[0], 1: colors[5]}
accent2 = {'Male': colors[1], 'Female': colors[4]}
n_cols = len(cols)
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
for i, col in enumerate(cols):
    sns.boxplot(df[[col, 'Gender']], x='Gender', y=col, ax=axes[i, 0], palette=accent2)
    sns.boxplot(df[[col, 'Purchased']], x='Purchased', y=col, ax=axes[i, 1], palette=accent1)

# %%
sns.pairplot(df, hue='Purchased')
plt.show()

# %% [markdown]
# <h1 style="text-align: center; font-family: 'Roboto', sans-serif; color: rgb(230, 131, 131); background-color: rgba(146, 146, 255, 0.5); padding: 30px; border-style: solid; border-radius: 10px;"> PreProcessing Pipeline </h1>

# %% [markdown]
# <h3 style="text-align: center; font-family: 'Roboto', sans-serif; color: rgba(146, 146, 255, 0.8); background-color: rgba(230, 131, 131, 0.3); padding: 10px; border-style: solid; border-radius: 10px;"> Pipeline </h3>

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import StandardScaler, OrdinalEncoder

# %%
categorical_cols = ['Gender']
numeric_cols = ['Age', 'EstimatedSalary']
columns_to_drop = list(set(df.columns)-set(categorical_cols+numeric_cols)) #drop any cols in df we r not considering

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('column_dropper', 'drop', columns_to_drop),
        ('num', StandardScaler(), numeric_cols),  
        ('cat', OrdinalEncoder(), categorical_cols)  
    ])

# %%
preprocessor.fit(df)
# Out:
# ColumnTransformer(transformers=[('column_dropper', 'drop',
#                                  ['User ID', 'Purchased']),
#                                 ('num', StandardScaler(),
#                                  ['Age', 'EstimatedSalary']),
#                                 ('cat', OrdinalEncoder(), ['Gender'])])

# %%
X = preprocessor.transform(df)
Y = df['Purchased']
X.shape, Y.shape
# Out:
# ((400, 3), (400,))

# %% [markdown]
# <h3 style="text-align: center; font-family: 'Roboto', sans-serif; color: rgba(146, 146, 255, 0.8); background-color: rgba(230, 131, 131, 0.3); padding: 10px; border-style: solid; border-radius: 10px;"> Train-Test Split </h3>

# %%
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.05)

# %% [markdown]
# <div style=" margin: 0% 20%; text-align: center; font-family: 'Roboto', sans-serif; color: rgba(146, 146, 230, 1); background-color: rgba(230, 131, 131, 0.15); padding: 20px; border-style: solid; border-radius: 10px;"> <p>Since training data is so limited, we will use Cross Validation instead of val set</p></div>

# %% [markdown]
# <h1 style="text-align: center; font-family: 'Roboto', sans-serif; color: rgb(230, 131, 131); background-color: rgba(146, 146, 255, 0.5); padding: 30px; border-style: solid; border-radius: 10px;"> Logistic Regression </h1>

# %% [markdown]
# <h3 style="text-align: center; font-family: 'Roboto', sans-serif; color: rgba(146, 146, 255, 0.8); background-color: rgba(230, 131, 131, 0.3); padding: 10px; border-style: solid; border-radius: 10px;"> Baseline Model </h3>

# %%
from sklearn.linear_model import LogisticRegressionCV
lr_classifier = LogisticRegressionCV()
lr_classifier.fit(x_train, y_train)
# Out:
# LogisticRegressionCV()

# %%
lr_classifier.score(x_test, y_test)
# Out:
# 0.9

# %% [markdown]
# <h1 style="text-align: center; font-family: 'Roboto', sans-serif; color: rgb(230, 131, 131); background-color: rgba(146, 146, 255, 0.5); padding: 30px; border-style: solid; border-radius: 10px;"> Pipeline </h1>

# %%
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', lr_classifier)
])

# %%
pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('column_dropper', 'drop',
#                                                   ['User ID', 'Purchased']),
#                                                  ('num', StandardScaler(),
#                                                   ['Age', 'EstimatedSalary']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['Gender'])])),
#                 ('model', LogisticRegressionCV())])
